# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("penguins")

vp = sns.violinplot(data=df, y = 'species' , x = 'bill_depth_mm', hue='sex' ,split = True, gridsize = 100, cut = 2)
